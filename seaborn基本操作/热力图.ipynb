# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
np.random.seed(0)
import seaborn as sns;
sns.set()

# %%
uniform_data = np.random.rand(3, 3)
print (uniform_data)
heatmap = sns.heatmap(uniform_data)
# Out:
# [[0.94466892 0.52184832 0.41466194]
#  [0.26455561 0.77423369 0.45615033]
#  [0.56843395 0.0187898  0.6176355 ]]

# %%
# 指定取值范围
ax = sns.heatmap(uniform_data, vmin=0.2, vmax=0.5)

# %%
# 指定中心值
normal_data = np.random.randn(3, 3)
print (normal_data)
ax = sns.heatmap(normal_data, center=0)
# Out:
# [[-1.25279536  0.77749036 -1.61389785]
#  [-0.21274028 -0.89546656  0.3869025 ]
#  [-0.51080514 -1.18063218 -0.02818223]]

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot("month", "year", "passengers")
print (flights)
ax = sns.heatmap(flights)
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
ax = sns.heatmap(flights, annot=True,fmt="d")

# %%
# 设置宽度
ax = sns.heatmap(flights, linewidths=.5)

# %%
# 指定颜色
ax = sns.heatmap(flights, cmap="YlGnBu")

# %%
ax = sns.heatmap(flights, cmap="YlGnBu",linewidths=1)

# %%
data = pd.DataFrame({"A":np.random.randint(1,100,100),
                     "B":np.random.randint(1,100,100),
                     "C":np.random.randint(1,100,100)})
data
# Out:
#      A   B   C
# 0   13  88  99
# 1   45  66  41
# 2   67  71  61
# 3   92  54  34
# 4   86  49  29
# ..  ..  ..  ..
# 95  59  59  72
# 96  44  37  95
# 97  56  70   7
# 98  19   7  46
# 99  46   4  31
#
# [100 rows x 3 columns]

# %%
data.corr()
# Out:
#           A         B         C
# A  1.000000 -0.009860  0.080721
# B -0.009860  1.000000  0.095364
# C  0.080721  0.095364  1.000000

# %%
ax = sns.heatmap(data.corr(), cmap="YlGnBu",linewidths=1)
